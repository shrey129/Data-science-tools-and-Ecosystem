# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# #### In this Notebook, Data Science Tools and Ecosystem are summarised.

# %% [markdown]
#  __Objective__
# The key takeaway from this notebook is
# - popular languages for DS
# - commonly used libraries for DS
# - DS tools
# - evaluating arithmetical operations

# %% [markdown]
# ##### Some of the popular language that data science uses are:
# 1. python
# 2. R
# 3. SQL

# %% [markdown]
# ##### Some of the commonly used libraries data science includes:
# 1. pandas
# 2. matpotlib
# 3. tensorflow

# %% [markdown]
# |       Data science tools        |
# |---------------------------------|
# |         Jupyter Notebook        |
# |           RStudio               |
# |           VS Code               |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
(3*4)+5
# This is a simple arithmetic expression to multiply and then add integers.
# Out:
# 17

# %%
200/60
# this will convert minutes into hours by diving by 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Shreya Gautam
